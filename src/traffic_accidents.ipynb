# %% [markdown]
# 1. import NYC_Accidents_2020.csv as a DataFrame

# %%
import pandas as pd
df = pd.read_csv("../data/raw/NYC_Accidents_2020.csv", skiprows=3)
df.head()
# Out:
#   CRASH DATE CRASH TIME   BOROUGH  ZIP CODE  LATITUDE  LONGITUDE  \
# 0    8/29/20   15:40:00     BRONX   10466.0  40.89210 -73.833760
# 1    8/29/20   21:00:00  BROOKLYN   11221.0  40.69050 -73.919914
# 2    8/29/20   18:20:00       NaN       NaN  40.81650 -73.946556
# 3    8/29/20    0:00:00     BRONX   10459.0  40.82472 -73.892960
# 4    8/29/20   17:10:00  BROOKLYN   11203.0  40.64989 -73.933890
#
#                      LOCATION   ON STREET NAME CROSS STREET NAME  \
# 0   POINT (-73.83376 40.8921)     PRATT AVENUE     STRANG AVENUE
# 1  POINT (-73.919914 40.6905)  BUSHWICK AVENUE   PALMETTO STREET
# 2  POINT (-73.946556 40.8165)         8 AVENUE               NaN
# 3  POINT (-73.89296 40.82472)              NaN               NaN
# 4  POINT (-73.93389 40.64989)              NaN               NaN
#
#        OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                  NaN  ...                    Unspecified
# 1                  NaN  ...                    Unspecified
# ...

# %% [markdown]
# first rows had to be eliminated with skiprows to make sure column names were correct.

# %% [markdown]
# 2. display columns and row samples

# %%
#show only the names of the columns
for col in df.columns:
    print(col)
# Out:
# CRASH DATE
# CRASH TIME
# BOROUGH
# ZIP CODE
# LATITUDE
# LONGITUDE
# LOCATION
# ON STREET NAME
# CROSS STREET NAME
# OFF STREET NAME
# NUMBER OF PERSONS INJURED
# NUMBER OF PERSONS KILLED
# NUMBER OF PEDESTRIANS INJURED
# NUMBER OF PEDESTRIANS KILLED
# NUMBER OF CYCLIST INJURED
# NUMBER OF CYCLIST KILLED
# NUMBER OF MOTORIST INJURED
# NUMBER OF MOTORIST KILLED
# CONTRIBUTING FACTOR VEHICLE 1
# CONTRIBUTING FACTOR VEHICLE 2
# CONTRIBUTING FACTOR VEHICLE 3
# CONTRIBUTING FACTOR VEHICLE 4
# CONTRIBUTING FACTOR VEHICLE 5
# COLLISION_ID
# VEHICLE TYPE CODE 1
# VEHICLE TYPE CODE 2
# VEHICLE TYPE CODE 3
# VEHICLE TYPE CODE 4
# VEHICLE TYPE CODE 5

# %%
#show the first 5 rows
df.head(5)
# Out:
#   CRASH DATE CRASH TIME   BOROUGH  ZIP CODE  LATITUDE  LONGITUDE  \
# 0    8/29/20   15:40:00     BRONX   10466.0  40.89210 -73.833760
# 1    8/29/20   21:00:00  BROOKLYN   11221.0  40.69050 -73.919914
# 2    8/29/20   18:20:00       NaN       NaN  40.81650 -73.946556
# 3    8/29/20    0:00:00     BRONX   10459.0  40.82472 -73.892960
# 4    8/29/20   17:10:00  BROOKLYN   11203.0  40.64989 -73.933890
#
#                      LOCATION   ON STREET NAME CROSS STREET NAME  \
# 0   POINT (-73.83376 40.8921)     PRATT AVENUE     STRANG AVENUE
# 1  POINT (-73.919914 40.6905)  BUSHWICK AVENUE   PALMETTO STREET
# 2  POINT (-73.946556 40.8165)         8 AVENUE               NaN
# 3  POINT (-73.89296 40.82472)              NaN               NaN
# 4  POINT (-73.93389 40.64989)              NaN               NaN
#
#        OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                  NaN  ...                    Unspecified
# 1                  NaN  ...                    Unspecified
# ...

# %%
#show a random sampling of 5 rows
df.sample(5)
# Out:
#       CRASH DATE CRASH TIME    BOROUGH  ZIP CODE  LATITUDE  LONGITUDE  \
# 6107      8/8/20   15:54:00   BROOKLYN   11211.0  40.71354 -73.938840
# 34007    4/14/20   18:30:00        NaN       NaN  40.81361 -73.913345
# 37682    3/21/20    2:00:00        NaN       NaN       NaN        NaN
# 71251     1/9/20   10:48:00     QUEENS   11365.0  40.73292 -73.800380
# 1984     8/22/20   16:10:00  MANHATTAN   10032.0  40.83406 -73.944885
#
#                           LOCATION                    ON STREET NAME  \
# 6107    POINT (-73.93884 40.71354)                               NaN
# 34007  POINT (-73.913345 40.81361)                   EAST 148 STREET
# 37682                          NaN  WILLIAMSBURG BRIDGE OUTER ROADWA
# 71251   POINT (-73.80038 40.73292)                         69 AVENUE
# 1984   POINT (-73.944885 40.83406)                   WEST 157 STREET
#
#       CROSS STREET NAME  OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# ...

# %%
#show the last 5 rows
df.tail(5)
# Out:
#       CRASH DATE CRASH TIME    BOROUGH  ZIP CODE   LATITUDE  LONGITUDE  \
# 74876     1/1/20   15:13:00      BRONX   10459.0  40.826810 -73.896510
# 74877     1/1/20    8:00:00   BROOKLYN   11235.0  40.582935 -73.959210
# 74878     1/1/20   11:36:00      BRONX   10461.0  40.848553 -73.830055
# 74879     1/1/20    1:45:00  MANHATTAN   10017.0  40.753624 -73.969440
# 74880     1/1/20   18:00:00     QUEENS   11367.0  40.726875 -73.830960
#
#                            LOCATION  ON STREET NAME CROSS STREET NAME  \
# 74876    POINT (-73.89651 40.82681)             NaN               NaN
# 74877   POINT (-73.95921 40.582935)             NaN               NaN
# 74878  POINT (-73.830055 40.848553)             NaN               NaN
# 74879   POINT (-73.96944 40.753624)  EAST 48 STREET          2 AVENUE
# 74880   POINT (-73.83096 40.726875)             NaN               NaN
#
#              OFF STREET NAME  ...   CONTRIBUTING FACTOR VEHICLE 2  \
# ...

# %% [markdown]
# 3. describe the rows and data types

# %%
#each column
df.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
#the type of each column
df.dtypes
# Out:
# CRASH DATE                        object
# CRASH TIME                        object
# BOROUGH                           object
# ZIP CODE                         float64
# LATITUDE                         float64
# LONGITUDE                        float64
# LOCATION                          object
# ON STREET NAME                    object
# CROSS STREET NAME                 object
# OFF STREET NAME                   object
# NUMBER OF PERSONS INJURED          int64
# NUMBER OF PERSONS KILLED           int64
# NUMBER OF PEDESTRIANS INJURED      int64
# NUMBER OF PEDESTRIANS KILLED       int64
# NUMBER OF CYCLIST INJURED          int64
# NUMBER OF CYCLIST KILLED           int64
# NUMBER OF MOTORIST INJURED         int64
# NUMBER OF MOTORIST KILLED          int64
# CONTRIBUTING FACTOR VEHICLE 1     object
# CONTRIBUTING FACTOR VEHICLE 2     object
# CONTRIBUTING FACTOR VEHICLE 3     object
# CONTRIBUTING FACTOR VEHICLE 4     object
# CONTRIBUTING FACTOR VEHICLE 5     object
# ...

# %%
#the number of non-missing values in each column
df.count(axis=0)
# Out:
# CRASH DATE                       74881
# CRASH TIME                       74881
# BOROUGH                          49140
# ZIP CODE                         49134
# LATITUDE                         68935
# LONGITUDE                        68935
# LOCATION                         68935
# ON STREET NAME                   55444
# CROSS STREET NAME                35681
# OFF STREET NAME                  19437
# NUMBER OF PERSONS INJURED        74881
# NUMBER OF PERSONS KILLED         74881
# NUMBER OF PEDESTRIANS INJURED    74881
# NUMBER OF PEDESTRIANS KILLED     74881
# NUMBER OF CYCLIST INJURED        74881
# NUMBER OF CYCLIST KILLED         74881
# NUMBER OF MOTORIST INJURED       74881
# NUMBER OF MOTORIST KILLED        74881
# CONTRIBUTING FACTOR VEHICLE 1    74577
# CONTRIBUTING FACTOR VEHICLE 2    59285
# CONTRIBUTING FACTOR VEHICLE 3     6765
# CONTRIBUTING FACTOR VEHICLE 4     1851
# CONTRIBUTING FACTOR VEHICLE 5      523
# COLLISION_ID                     74881
# ...

# %% [markdown]
# list out the columns that look like they have the "wrong" (or too wide) type
# and next to the column name,
# specify what type the column should probably be
# lastly, preview the remainder of the instructions and write out any data transformations
# or cleaning that you think will be necessary to complete this part of the homework
#
# * date and time could be Date objects
# * zip code could be int
# * street names could be String
# * Contributing factors could be String
# * Vehicle types could be String
#
#
# * 'Unspecified' needs to be read as a NaN
# * Lots of redundancies -- to decide which columns to get rid of I need to decide how much information I need to answer specific questions (ex., if we're not conducting research on what type of cars get into accidents that I can remove all the vehicle type code columns)
# * The data allows for up to 5 contributing vehicles to be documented so we have to see if all of these columns are necessary

# %%
df['COLLISION_ID'].sample(5)
# Out:
# 68973    4273021
# 10094    4332714
# 32030    4311013
# 8410     4334313
# 24333    4320068
# Name: COLLISION_ID, dtype: int64

# %% [markdown]
# Collision ID is not relevant to our research so we can remove it.

# %%
df=df.drop('COLLISION_ID', axis=1)

# %%
df.nunique()
# Out:
# CRASH DATE                         242
# CRASH TIME                        1440
# BOROUGH                              5
# ZIP CODE                           198
# LATITUDE                         29106
# LONGITUDE                        23552
# LOCATION                         36749
# ON STREET NAME                    4009
# CROSS STREET NAME                 4405
# OFF STREET NAME                  17451
# NUMBER OF PERSONS INJURED           12
# NUMBER OF PERSONS KILLED             5
# NUMBER OF PEDESTRIANS INJURED        6
# NUMBER OF PEDESTRIANS KILLED         2
# NUMBER OF CYCLIST INJURED            4
# NUMBER OF CYCLIST KILLED             2
# NUMBER OF MOTORIST INJURED          12
# NUMBER OF MOTORIST KILLED            5
# CONTRIBUTING FACTOR VEHICLE 1       55
# CONTRIBUTING FACTOR VEHICLE 2       45
# CONTRIBUTING FACTOR VEHICLE 3       29
# CONTRIBUTING FACTOR VEHICLE 4       12
# CONTRIBUTING FACTOR VEHICLE 5        6
# VEHICLE TYPE CODE 1                272
# ...

# %%
df.iloc[:, 10:18]
# Out:
#        NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# 0                              0                         0
# 1                              2                         0
# 2                              1                         0
# 3                              0                         0
# 4                              0                         0
# ...                          ...                       ...
# 74876                          0                         0
# 74877                          0                         0
# 74878                          0                         0
# 74879                          0                         0
# 74880                          2                         0
#
#        NUMBER OF PEDESTRIANS INJURED  NUMBER OF PEDESTRIANS KILLED  \
# 0                                  0                             0
# 1                                  0                             0
# ...

# %% [markdown]
# The number of persons injured/killed is specified in later columns with whether the person is a pedestrian/cyclist etc. We can remove everything except the first two columns for our purposes.

# %%
df = df.drop(['NUMBER OF PEDESTRIANS INJURED', 'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED', 'NUMBER OF MOTORIST KILLED'], axis=1)

# %%
df=df.fillna(0)
df['ZIP CODE'] = df['ZIP CODE'].astype(int)
df['ZIP CODE']
# Out:
# 0        10466
# 1        11221
# 2            0
# 3        10459
# 4        11203
#          ...
# 74876    10459
# 74877    11235
# 74878    10461
# 74879    10017
# 74880    11367
# Name: ZIP CODE, Length: 74881, dtype: int32

# %% [markdown]
# 5. determine the top three streets(Use the ON STREET NAME column) that had the most accidents

# %%
#show the street name and the number of accidents occurred on each street

#normalizing all street names
df['OFF STREET NAME'] = df['OFF STREET NAME'].str.upper()
df['ON STREET NAME'] = df['ON STREET NAME'].str.upper()
df['CROSS STREET NAME'] = df['CROSS STREET NAME'].str.upper()


s1=df['OFF STREET NAME'].value_counts()
s2=df['ON STREET NAME'].value_counts()
s3=df['CROSS STREET NAME'].value_counts()
streets = pd.concat([s1, s2, s3])

streets.sort_values(ascending=False)
# Out:
# BELT PARKWAY                  1245
# LONG ISLAND EXPRESSWAY         745
# BROOKLYN QUEENS EXPRESSWAY     740
# FDR DRIVE                      729
# MAJOR DEEGAN EXPRESSWAY        591
#                               ...
# 3619 AVENUE H                    1
# 400 BROOK AVENUE                 1
# 51-18 SIMONSON STREET            1
# 342 ETNA STREET                  1
# 151 STREET                       1
# Length: 25476, dtype: int64

# %% [markdown]
# 6. shows the number of accidents that occurred at each borough

# %%
borough_count = df['BOROUGH'].value_counts(dropna=False)
borough_count
# Out:
# NaN              25741
# BROOKLYN         16907
# QUEENS           14017
# BRONX             9417
# MANHATTAN         7353
# STATEN ISLAND     1446
# Name: BOROUGH, dtype: int64

# %%
#rename and remove NaN
borough_count['OTHER'] = borough_count[0]
borough_count = borough_count[1:]

borough_count
# Out:
# BROOKLYN         16907
# QUEENS           14017
# BRONX             9417
# MANHATTAN         7353
# STATEN ISLAND     1446
# OTHER            25741
# Name: BOROUGH, dtype: int64

# %%
#show a visualization that allows comparison of the number of the accidents
import matplotlib.pyplot as plt

plt.bar(borough_count.index, borough_count.values, 0.8)
plt.ylabel('Accidents')
plt.xlabel('Borough')
plt.title('Traffic Accidents by Borough')
plt.xticks(borough_count.index, rotation=45)
# Out:
# ([<matplotlib.axis.XTick at 0x24bececda30>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %% [markdown]
# 7. calculate summary statistics for the number of persons injured in all NYC and for a couple of selected boroughs (you can choose the two boroughs)

# %%
#selecting for MANHATTAN and BROOKLYN

c1 = df[df['BOROUGH']==('MANHATTAN')]
man_injuries = c1.loc[:, ['BOROUGH', 'NUMBER OF PERSONS INJURED']].dropna()
man_injuries = man_injuries[man_injuries['NUMBER OF PERSONS INJURED'] > 0]

c2 = df[df['BOROUGH']==('BROOKLYN')]
bro_injuries = c2.loc[:, ['BOROUGH', 'NUMBER OF PERSONS INJURED']].dropna()
bro_injuries = bro_injuries[bro_injuries['NUMBER OF PERSONS INJURED'] > 0]

all_injuries = df.loc[:, ['BOROUGH', 'NUMBER OF PERSONS INJURED']].dropna()
all_injuries = all_injuries[all_injuries['NUMBER OF PERSONS INJURED'] > 0]

all_injuries.describe()
# Out:
#        NUMBER OF PERSONS INJURED
# count               12791.000000
# mean                    1.299117
# std                     0.728166
# min                     1.000000
# 25%                     1.000000
# 50%                     1.000000
# 75%                     1.000000
# max                    15.000000

# %%
man_injuries.describe()
# Out:
#        NUMBER OF PERSONS INJURED
# count                1800.000000
# mean                    1.195000
# std                     0.561184
# min                     1.000000
# 25%                     1.000000
# 50%                     1.000000
# 75%                     1.000000
# max                     5.000000

# %%
bro_injuries.describe()
# Out:
#        NUMBER OF PERSONS INJURED
# count                4557.000000
# mean                    1.321922
# std                     0.764778
# min                     1.000000
# 25%                     1.000000
# 50%                     1.000000
# 75%                     1.000000
# max                    15.000000

# %% [markdown]
# Brooklyn has a vastly higher count of injuries, and on average more people get injured by traffic accidents in Brooklyn than they do in NYC as a whole. Brooklyn also has the highest standard deviation, and shares max values with all_injuries, which may indicate that the highest casualty count incidents in all of NYC occurred in Brooklyn. For both Brooklyn and Manhattan, however, the majority of injuries caused by traffic accidents involve just 1 person.

# %% [markdown]
# 8. what are the distributions of accidents based on the geo location (latitude & longitude)?

# %%
geo = df.loc[:, ['LATITUDE', 'LONGITUDE', 'BOROUGH']].dropna()
geo = geo[geo['LATITUDE'] > 0]
geo.describe()
# Out:
#            LATITUDE     LONGITUDE
# count  47694.000000  47694.000000
# mean      40.723822    -73.909729
# std        0.081883      0.078352
# min       40.504482    -74.249760
# 25%       40.664642    -73.960014
# 50%       40.712473    -73.914490
# 75%       40.779920    -73.863710
# max       40.912884    -73.700584

# %%
fig, ax = plt.subplots(figsize=(5, 5))

colors = {'MANHATTAN':'blue', 'BROOKLYN':'orange', 'BRONX':'green', 'STATEN ISLAND':'red', 'QUEENS':'purple'}

ax.scatter(geo['LATITUDE'], geo['LONGITUDE'], c=geo['BOROUGH'].map(colors))

# %% [markdown]
# 9. shows the covariance between each pair of the columns

# %%
import numpy as np

#covariance between number of persons injured and longtitude

df['NUMBER OF PERSONS INJURED'].cov(df['LONGITUDE'])
# Out:
# 0.26131882772187887

# %% [markdown]
# The covariance is slightly greater than 0 which indices a slightly positive correlation between longitude and number of people injured. I chose longitude to be a numerical way to represent otherwise categorical location data.

# %% [markdown]
# 10. which month did the most number of accidents occur?

# %%
df['CRASH DATE']=pd.to_datetime(df['CRASH DATE'])
df['CRASH DATE'].dt.month_name().value_counts()
# Out:
# January     14287
# February    13684
# March       11057
# July         9225
# August       8747
# June         7616
# May          6149
# April        4116
# Name: CRASH DATE, dtype: int64

# %% [markdown]
# Months where accidents reach a lull indicate better weather for safer road conditions.
